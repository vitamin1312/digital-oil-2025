# %%
import numpy as np # библиотека для работы с чиселками
import pandas as pd # data processing, работа с CSV файлами
import matplotlib.pyplot as plt # для графики
import seaborn as sns # аналогично
import ast

# %%
dataset = pd.read_excel("./1 день/train_dataset/static_data/train_test_static_data.xlsx", engine='openpyxl')
dataset.head(5)
# Out:
#    ID скважины                              Паспортные данные ЭЦН  \
# 0        10001  {'name': 'ЭЦНМТ 5А-200DP', 'rate_nom_sm3day': ...
# 1        10002  {'name': 'ЭЦН5А-200', 'rate_nom_sm3day': 200.0...
# 2        10003  {'name': '30.1ЭЦНДИ5А-160М', 'rate_nom_sm3day'...
# 3        10004  {'name': 'ВНН5А-100', 'rate_nom_sm3day': 100.0...
# 4        10005  {'name': 'ЭЦНМТ 5А-80DP', 'rate_nom_sm3day': 8...
#
#                                   Характеристики ПЭД  \
# 0  {"manufacturer": "\u0421\u0426 \u042d\u041f\u0...
# 1  {"manufacturer": "\u041b\u044b\u0441\u044c\u04...
# 2  {"manufacturer": "\u0411\u043e\u0440\u0435\u04...
# 3  {"manufacturer": "\u041d\u043e\u0432\u043e\u04...
# 4  {"manufacturer": "Schlumberger", "name": "\u04...
#
#                                        Инклинометрия  \
# 0  {'measured': [10.0, 20.0, 30.0, 40.0, 50.0, 60...
# 1  {'measured': [0.0, 10.0, 20.0, 30.0, 40.0, 50....
# 2  {'measured': [0.0, 10.0, 20.0, 30.0, 40.0, 50....
# ...

# %%
column_name = 'Паспортные данные ЭЦН'
# Преобразуем строку в словарь
dataset[column_name] = dataset[column_name].apply(ast.literal_eval)

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[0]
columns_after = dataset.columns[2]
dataset = dataset.drop(columns=[column_name])
cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]


# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'Характеристики ПЭД',
#  'Инклинометрия',
#  'ЭК',
#  'НКТ',
#  'Пакер',
#  'Количество ступеней насоса',
#  'Сепаратор',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
#  'Относительная плотность воды',
#  'Пластовое давление',
#  'Пластовая температура',
#  'Штуцер',
#  'Линейная температура']

# %%
pd.options.display.max_rows = 100

# %%
dataset['rate_nom_sm3day']
# Out:
# 0     200.0
# 1     200.0
# 2     160.0
# 3     100.0
# 4      85.0
# 5      80.0
# 6      60.0
# 7     200.0
# 8     160.0
# 9      80.0
# 10    200.0
# 11     85.0
# 12     80.0
# 13    124.0
# 14     80.0
# 15     80.0
# 16     59.0
# 17     85.0
# 18    250.0
# 19     44.0
# 20     79.0
# 21     60.0
# 22     79.0
# 23     80.0
# 24     60.0
# 25    125.0
# 26    165.0
# 27     85.0
# 28     80.0
# 29    200.0
# 30    200.0
# 31     80.0
# 32    125.0
# 33     80.0
# 34    125.0
# 35     60.0
# 36     80.0
# 37     79.0
# 38     60.0
# 39     45.0
# 40    280.0
# 41     59.0
# 42    100.0
# 43     80.0
# 44    160.0
# 45     45.0
# 46     80.0
# 47     59.0
# 48    200.0
# 49     35.0
# 50    100.0
# 51     80.0
# 52    125.0
# 53     80.0
# 54     66.0
# 55     45.0
# 56     80.0
# 57    159.0
# 58    320.0
# 59    320.0
# 60     60.0
# 61     60.0
# 62    100.0
# 63     80.0
# 64     80.0
# 65     44.0
# 66    100.0
# 67     60.0
# 68     60.0
# 69    100.0
# 70    125.0
# ...

# %%
dataset.to_csv('a_bit_changed_dataset.csv', index=False, encoding='utf-8-sig')

# %%
dataset.columns.tolist()

# %%
column_name = 'Инклинометрия'
# Преобразуем строку в словарь
dataset[column_name] = dataset[column_name].apply(ast.literal_eval)

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[14]
columns_after = dataset.columns[16]
dataset = dataset.drop(columns=[column_name])
cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]


# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'Характеристики ПЭД',
#  'measured',
#  'absolute',
#  'ЭК',
#  'НКТ',
#  'Пакер',
#  'Количество ступеней насоса',
#  'Сепаратор',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
#  'Относительная плотность воды',
#  'Пластовое давление',
#  'Пластовая температура',
#  'Штуцер',
#  'Линейная температура']

# %%
column_name = 'ЭК'
# Преобразуем строку в словарь
dataset[column_name] = dataset[column_name].apply(ast.literal_eval)

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[16]
columns_after = dataset.columns[18]
dataset = dataset.drop(columns=[column_name])
cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]


# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'Характеристики ПЭД',
#  'measured',
#  'absolute',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'НКТ',
#  'Пакер',
#  'Количество ступеней насоса',
#  'Сепаратор',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
#  'Относительная плотность воды',
#  'Пластовое давление',
#  'Пластовая температура',
#  'Штуцер',
#  'Линейная температура']

# %%
column_name = 'НКТ'
# Преобразуем строку в словарь
dataset[column_name] = dataset[column_name].apply(ast.literal_eval)

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[19]
columns_after = dataset.columns[21]
dataset = dataset.drop(columns=[column_name])
cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]


# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'Характеристики ПЭД',
#  'measured',
#  'absolute',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'Пакер',
#  'Количество ступеней насоса',
#  'Сепаратор',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
#  'Относительная плотность воды',
#  'Пластовое давление',
#  'Пластовая температура',
#  'Штуцер',
#  'Линейная температура']

# %%
dataset.columns.values[20] = 'NKT_bottom_depth'
dataset.columns.values[21] = 'NKT_sections_info'
dataset.columns.values[22] = 'NKT_roughness'

# %%
dataset.to_csv('a_bit_changed_dataset.csv', index=False, encoding='utf-8-sig')

# %%
column_name = 'Сепаратор'
# Преобразуем строку в словарь
dataset[column_name] = dataset[column_name].apply(ast.literal_eval)

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[24]
columns_after = dataset.columns[26]
dataset = dataset.drop(columns=[column_name])
cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]


# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'Характеристики ПЭД',
#  'measured',
#  'absolute',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'NKT_bottom_depth',
#  'NKT_sections_info',
#  'NKT_roughness',
#  'Пакер',
#  'Количество ступеней насоса',
#  'k_gas_sep',
#  'sep_name',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
#  'Относительная плотность воды',
#  'Пластовое давление',
#  'Пластовая температура',
#  'Штуцер',
#  'Линейная температура']

# %%
import json

def safe_parse(val):
    try:
        return json.loads(val)
    except Exception as e:
        print("Ошибка для значения:", val)
        print("Причина:", e)
        return None

column_name = 'Характеристики ПЭД'
# Преобразуем строку в словарь

# допустим, колонка уже есть
if column_name in dataset.columns:
    dataset[column_name] = dataset[column_name].apply(
        lambda x: safe_parse(x) if isinstance(x, str) else x
    )

# Разделим словари по ключам
expanded_part = dataset[column_name].apply(pd.Series)

columns_before = dataset.columns[13]
columns_after = dataset.columns[15]

dataset = dataset.drop(columns=[column_name])

cols_before = dataset.loc[:, :columns_before]
cols_after = dataset.loc[:, columns_after:]

# Объединяем обратно в основной датафрейм
dataset = pd.concat([cols_before, expanded_part, cols_after], axis=1)

# Посмотрим результат
dataset.head(5)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# ...

# %%
dataset.columns.values[15] = 'name_PED'
dataset.columns.values[27] = 'eff_points_PED'
dataset = dataset.drop(columns=['sep_name'])

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'manufacturer',
#  'name_PED',
#  'd_motor_mm',
#  'motor_nom_i',
#  'motor_amp_idle',
#  'motor_nom_power',
#  'motor_nom_voltage',
#  'motor_nom_eff',
#  'motor_nom_cosf',
#  'motor_nom_freq',
#  'load_points',
#  'amperage_points',
#  'cosf_points',
#  'eff_points_PED',
#  'rpm_points',
#  'measured',
#  'absolute',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'NKT_bottom_depth',
#  'NKT_sections_info',
#  'NKT_roughness',
#  'Пакер',
#  'Количество ступеней насоса',
#  'k_gas_sep',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
# ...

# %%
dataset.to_csv('changed_static_dataset.csv', index=False, encoding='utf-8-sig')

# %%
dataset = pd.read_csv('changed_static_dataset.csv', encoding='utf-8-sig')

# %%
dataset['k_gas_sep'] = dataset['k_gas_sep'].fillna(0.7)

# %%
#Заменяем все Nan на {"d": 0.0}
dataset['Штуцер'] = dataset['Штуцер'].apply(lambda x: "{'d': 0.0}" if pd.isna(x) else x)

# %%
column_name = 'Штуцер'


# 2. Преобразуем строки в словари
dataset[column_name] = dataset[column_name].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# 3. Если это словарь с 1 ключом — извлекаем значение
dataset[column_name] = dataset[column_name].apply(
    lambda x: list(x.values())[0] if isinstance(x, dict) and len(x) == 1 else x
)
# Посмотрим результат
dataset.head(5)
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.columns.tolist()
# Out:
# ['ID скважины',
#  'name',
#  'rate_nom_sm3day',
#  'rate_opt_min_sm3day',
#  'rate_opt_max_sm3day',
#  'freq_Hz',
#  'rate_points',
#  'head_points',
#  'power_points',
#  'eff_points',
#  'stages_max',
#  'rate_max_sm3day',
#  'slip_nom_rpm',
#  'eff_max',
#  'manufacturer',
#  'name_PED',
#  'd_motor_mm',
#  'motor_nom_i',
#  'motor_amp_idle',
#  'motor_nom_power',
#  'motor_nom_voltage',
#  'motor_nom_eff',
#  'motor_nom_cosf',
#  'motor_nom_freq',
#  'load_points',
#  'amperage_points',
#  'cosf_points',
#  'eff_points_PED',
#  'rpm_points',
#  'measured',
#  'absolute',
#  'bottom_depth',
#  'sections_info',
#  'roughness',
#  'NKT_bottom_depth',
#  'NKT_sections_info',
#  'NKT_roughness',
#  'Пакер',
#  'Количество ступеней насоса',
#  'k_gas_sep',
#  'КПД станции управления',
#  'КПД трансформатора',
#  'Глубина установки насоса',
#  'Удельное сопротивление кабеля',
#  'Длина кабеля',
#  'Относительная плотность газа',
#  'Относительная плотность нефти',
# ...

# %%
dataset['Nsections_info']
# Out:
# 0     [{'MD': 699.01, 'd': 62.0}, {'MD': 1638.28, 'd...
# 1     [{'MD': 1005.59, 'd': 62.0}, {'MD': 1311.22, '...
# 2     [{'MD': 846.78, 'd': 62.0}, {'MD': 917.49, 'd'...
# 3     [{'MD': 748.59, 'd': 62.0}, {'MD': 1503.590000...
# 4     [{'MD': 594.59, 'd': 62.0}, {'MD': 949.28, 'd'...
# 5     [{'MD': 1209.01, 'd': 62.0}, {'MD': 1647.47, '...
# 6     [{'MD': 511.48, 'd': 62.0}, {'MD': 1002.6, 'd'...
# 7     [{'MD': 978.7, 'd': 62.0}, {'MD': 1475.69, 'd'...
# 8     [{'MD': 287.84, 'd': 49.0}, {'MD': 1408.11, 'd...
# 9     [{'MD': 748.72, 'd': 62.0}, {'MD': 2249.51, 'd...
# 10    [{'MD': 619.74, 'd': 76.0}, {'MD': 1062.49, 'd...
# 11                         [{'MD': 1880.97, 'd': 62.0}]
# 12    [{'MD': 703.8, 'd': 62.0}, {'MD': 990.59999999...
# 13                         [{'MD': 2828.52, 'd': 62.0}]
# 14    [{'MD': 600.6, 'd': 62.0}, {'MD': 982.08, 'd':...
# 15    [{'MD': 496.56, 'd': 62.0}, {'MD': 2081.08, 'd...
# 16    [{'MD': 310.05, 'd': 62.0}, {'MD': 1502.31, 'd...
# ...

# %%
dataset['NKT_sections_info']
# Out:
# 0     [{'MD': 699.01, 'd': 62.0}, {'MD': 1638.28, 'd...
# 1     [{'MD': 1005.59, 'd': 62.0}, {'MD': 1311.22, '...
# 2     [{'MD': 846.78, 'd': 62.0}, {'MD': 917.49, 'd'...
# 3     [{'MD': 748.59, 'd': 62.0}, {'MD': 1503.590000...
# 4     [{'MD': 594.59, 'd': 62.0}, {'MD': 949.28, 'd'...
# 5     [{'MD': 1209.01, 'd': 62.0}, {'MD': 1647.47, '...
# 6     [{'MD': 511.48, 'd': 62.0}, {'MD': 1002.6, 'd'...
# 7     [{'MD': 978.7, 'd': 62.0}, {'MD': 1475.69, 'd'...
# 8     [{'MD': 287.84, 'd': 49.0}, {'MD': 1408.11, 'd...
# 9     [{'MD': 748.72, 'd': 62.0}, {'MD': 2249.51, 'd...
# 10    [{'MD': 619.74, 'd': 76.0}, {'MD': 1062.49, 'd...
# 11                         [{'MD': 1880.97, 'd': 62.0}]
# 12    [{'MD': 703.8, 'd': 62.0}, {'MD': 990.59999999...
# 13                         [{'MD': 2828.52, 'd': 62.0}]
# 14    [{'MD': 600.6, 'd': 62.0}, {'MD': 982.08, 'd':...
# 15    [{'MD': 496.56, 'd': 62.0}, {'MD': 2081.08, 'd...
# 16    [{'MD': 310.05, 'd': 62.0}, {'MD': 1502.31, 'd...
# ...

# %%
for i in range (0, len(dataset['Штуцер'])):
    if dataset['Штуцер'][i] == 0.0:
        print(dataset['NKT_sections_info'].iloc[i][0]['d'])
        dataset['Штуцер'][i] = dataset['NKT_sections_info'].iloc[i][0]['d']
    print(dataset['Штуцер'][i])
    #return row['Штуцер']

#dataset['Штуцер'] = dataset.apply(replace_zero_with_d, axis=1)
# Out:
# 32.0
# 18.0
# 18.0
# 62.0
# 32.0
# 18.0
# 32.0
# 18.0
# 18.0
# 32.0
# 76.0
# 32.0
# 62.0
# 62.0
# 62.0
# 62.0
# 62.0
# 32.0
# 18.0
# 32.0
# 62.0
# 62.0
# 32.0
# 32.0
# 32.0
# 18.0
# 62.0
# 32.0
# 62.0
# 18.0
# 32.0
# 32.0
# 32.0
# 62.0
# 62.0
# 62.0
# 32.0
# 32.0
# 32.0
# 32.0
# 62.0
# 62.0
# 32.0
# 32.0
# 62.0
# 32.0
# 32.0
# 62.0
# 62.0
# 32.0
# 62.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 62.0
# 62.0
# 32.0
# 62.0
# 32.0
# 62.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 76.0
# 32.0
# 76.0
# 62.0
# 32.0
# 62.0
# 62.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 62.0
# 62.0
# 62.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 32.0
# 62.0
# 62.0
# 32.0
# 32.0
# 32.0
# 62.0
# 50.0
# 76.0
# 32.0

# %%
def parse_sections(row):
    try:
        if isinstance(row, str):
            return ast.literal_eval(row)
        return row
    except (ValueError, SyntaxError):
        return []

dataset['sections_info'] = dataset['sections_info'].apply(parse_sections)
dataset['NKT_sections_info'] = dataset['NKT_sections_info'].apply(parse_sections)
dataset['sections_info'].iloc[0][0]['d']
# Out:
# 146.8

# %%
dataset['Штуцер']
# Out:
# 0     32.0
# 1     18.0
# 2     18.0
# 3     62.0
# 4     32.0
# 5     18.0
# 6     32.0
# 7     18.0
# 8     18.0
# 9     32.0
# 10    76.0
# 11    32.0
# 12    62.0
# 13    62.0
# 14    62.0
# 15    62.0
# 16    62.0
# 17    32.0
# 18    18.0
# 19    32.0
# 20    62.0
# 21    62.0
# 22    32.0
# 23    32.0
# 24    32.0
# 25    18.0
# 26    62.0
# 27    32.0
# 28    62.0
# 29    18.0
# 30    32.0
# 31    32.0
# 32    32.0
# 33    62.0
# 34    62.0
# 35    62.0
# 36    32.0
# 37    32.0
# 38    32.0
# 39    32.0
# 40    62.0
# 41    62.0
# 42    32.0
# 43    32.0
# 44    62.0
# 45    32.0
# 46    32.0
# 47    62.0
# 48    62.0
# 49    32.0
# 50    62.0
# 51    32.0
# 52    32.0
# 53    32.0
# 54    32.0
# 55    32.0
# 56    62.0
# 57    62.0
# 58    32.0
# 59    62.0
# 60    32.0
# 61    62.0
# 62    32.0
# 63    32.0
# 64    32.0
# 65    32.0
# 66    32.0
# 67    76.0
# 68    32.0
# 69    76.0
# 70    62.0
# 71    32.0
# 72    62.0
# 73    62.0
# 74    32.0
# 75    32.0
# ...

# %%
dataset.head()
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset.head()
# Out:
#    ID скважины              name  rate_nom_sm3day  rate_opt_min_sm3day  \
# 0        10001    ЭЦНМТ 5А-200DP            200.0                161.0
# 1        10002         ЭЦН5А-200            200.0                150.0
# 2        10003  30.1ЭЦНДИ5А-160М            160.0                125.0
# 3        10004         ВНН5А-100            100.0                 70.0
# 4        10005     ЭЦНМТ 5А-80DP             85.0                 53.0
#
#    rate_opt_max_sm3day  freq_Hz  \
# 0                260.0     50.0
# 1                250.0     50.0
# 2                200.0     50.0
# 3                140.0     50.0
# 4                113.0     50.0
#
#                                          rate_points  \
# 0  [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1           [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2  [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3             [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4  [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
#
# ...

# %%
dataset["rate_points"]
# Out:
# 0     [10.865, 21.729, 32.594, 43.458, 54.323, 65.18...
# 1              [0.0, 100.0, 150.0, 200.0, 250.0, 300.0]
# 2     [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 3                [0.0, 40.0, 70.0, 100.0, 140.0, 160.0]
# 4     [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
# 5     [0.0, 21.0, 42.0, 60.0, 70.0, 80.0, 89.0, 100....
# 6     [0.0, 10.0, 20.0, 35.0, 40.0, 50.0, 60.0, 70.0...
# 7     [0.0, 40.42, 128.3, 139.39, 178.3, 200.49, 214...
# 8     [0.0, 50.0, 75.0, 100.0, 125.0, 150.0, 160.0, ...
# 9     [0.0, 20.0, 40.0, 60.0, 70.0, 80.0, 90.0, 100....
# 10             [0.0, 100.0, 157.0, 200.0, 242.0, 310.0]
# 11    [0.0, 10.0, 20.0, 30.0, 40.0, 50.0, 53.0, 60.0...
# 12    [0.0, 20.0, 40.0, 60.0, 80.0, 85.0, 100.0, 120...
# 13    [0.0, 20.0, 40.0, 60.0, 80.0, 95.0, 120.0, 124...
# 14         [0.0, 30.0, 60.0, 80.0, 105.0, 130.0, 175.0]
# 15         [0.0, 30.0, 60.0, 80.0, 105.0, 130.0, 175.0]
# 16          [0.0, 20.0, 40.0, 59.0, 75.0, 100.0, 120.0]
# ...

# %%
dataset.dtypes
# Out:
# ID скважины                        int64
# name                              object
# rate_nom_sm3day                  float64
# rate_opt_min_sm3day              float64
# rate_opt_max_sm3day              float64
# freq_Hz                          float64
# rate_points                       object
# head_points                       object
# power_points                      object
# eff_points                        object
# stages_max                       float64
# rate_max_sm3day                  float64
# slip_nom_rpm                     float64
# eff_max                          float64
# manufacturer                      object
# name_PED                          object
# d_motor_mm                       float64
# motor_nom_i                      float64
# motor_amp_idle                   float64
# motor_nom_power                  float64
# motor_nom_voltage                float64
# motor_nom_eff                    float64
# motor_nom_cosf                   float64
# ...
